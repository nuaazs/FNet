# %%
from rt_utils import RTStructBuilder
import matplotlib.pyplot as plt

# Load existing RT Struct. Requires the series path and existing RT Struct path
rtstruct = RTStructBuilder.create_from(
  dicom_series_path="/home/zhaosheng/4dct/cao wu jun/Resp  3.0  B30f  40% Pi", 
  rt_struct_path="/home/zhaosheng/4dct/cao wu jun/ARIA RadOnc Structure Sets/RS.1.2.246.352.205.4627839360466632183.6908298268160168110.dcm", 
)

# View all of the ROI names from within the image
print(rtstruct.get_roi_names())
# Out:
# ['BODY', 'GTVp']

# %%
import os
import pydicom

ds = pydicom.dcmread("/home/zhaosheng/4dct/cao wu jun/ARIA RadOnc Structure Sets/RS.1.2.246.352.205.4627839360466632183.6908298268160168110.dcm")

# %%
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 170
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.246.352.205.4627839360466632183.6908298268160168110
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.246.352.70.2.1.7
# -------------------------------------------------
# (0008, 0012) Instance Creation Date              DA: '20190107'
# (0008, 0013) Instance Creation Time              TM: '182814.516000'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.205.4627839360466632183.6908298268160168110
# (0008, 0020) Study Date                          DA: '20181221'
# (0008, 0030) Study Time                          TM: '094907.440000'
# (0008, 0050) Accession Number                    SH: '2018122015034'
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: 'RISCE'
# (0008, 1010) Station Name                        SH: 'ARIA'
# (0008, 1030) Study Description                   LO: 'AbdomenCT'
# (0008, 103e) Series Description                  LO: 'ARIA RadOnc Structure Sets'
# (0008, 1090) Manufacturer's Model Name           LO: 'ARIA RadOnc'
# (0010, 0010) Patient's Name                      PN: 'CAO WU JUN'
# (0010, 0020) Patient ID                          LO: '276473'
# (0010, 0030) Patient's Birth Date                DA: '19500830'
# (0010, 0032) Patient's Birth Time                TM: '000000'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1000) Device Serial Number                LO: '541225649738'
# (0018, 1020) Software Versions                   LO: '13.6.32'
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.186.8086182178238.20181221093924248.972
# (0020, 000e) Series Instance UID                 UI: 1.2.246.352.71.2.541225649738.8925872.20181221151056
# (0020, 0010) Study ID                            SH: '217'
# (0020, 0011) Series Number                       IS: "15"
# (0020, 0013) Instance Number                     IS: "8"
# (3006, 0002) Structure Set Label                 SH: 'CT40'
# (3006, 0006) Structure Set Description           ST: '|AcurosXB-13.5'
# (3006, 0008) Structure Set Date                  DA: '20181221'
# (3006, 0009) Structure Set Time                  TM: '151104.400000'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.67009.30000018122100114931700000032
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Study Component Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.186.8086182178238.20181221093924248.972
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002437
#          (3006, 0016)  Contour Image Sequence  127 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002439
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002441
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002443
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002445
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002447
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002449
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002451
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002453
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002455
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002457
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002459
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002461
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002463
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002465
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002467
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002469
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002471
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002473
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002475
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002477
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002479
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002481
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002483
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002485
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002487
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002489
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002491
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002493
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002495
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002497
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002499
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002501
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002503
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002505
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002507
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002509
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002511
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002513
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002515
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002517
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002519
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002521
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002523
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002525
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002527
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002529
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002531
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002533
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002535
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002537
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002539
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002541
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002543
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002545
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002547
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002549
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002551
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002553
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002555
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002557
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002559
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002561
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002563
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002438
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002440
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002442
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002444
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002446
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002448
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002450
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002452
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002454
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002456
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002458
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002460
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002462
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002464
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002466
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002468
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002470
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002472
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002474
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002476
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002478
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002480
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002482
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002484
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002486
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002488
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002490
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002492
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002494
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002496
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002498
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002500
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002502
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002504
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002506
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002508
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002510
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002512
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002514
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002516
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002518
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002520
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002522
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002524
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002526
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002528
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002530
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002532
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002534
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002536
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002538
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002540
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002542
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002544
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002546
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002548
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002550
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002552
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002554
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002556
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002558
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002560
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002562
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002564
#             ---------
#          ---------
#       ---------
#    ---------
# (3006, 0020)  Structure Set ROI Sequence  2 item(s) ----
#    (3006, 0022) ROI Number                          IS: "1"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.67009.30000018122100114931700000032
#    (3006, 0026) ROI Name                            LO: 'BODY'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
#    (3006, 0022) ROI Number                          IS: "2"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.67009.30000018122100114931700000032
#    (3006, 0026) ROI Name                            LO: 'GTVp'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
# (3006, 0039)  ROI Contour Sequence  2 item(s) ----
#    (3006, 002a) ROI Display Color                   IS: [0, 255, 0]
#    (3006, 0040)  Contour Sequence  187 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002564
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "680"
#       (3006, 0050) Contour Data                        DS: Array of 2040 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002564
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "154"
#       (3006, 0050) Contour Data                        DS: Array of 462 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002563
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "674"
#       (3006, 0050) Contour Data                        DS: Array of 2022 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002563
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "154"
#       (3006, 0050) Contour Data                        DS: Array of 462 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002562
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "672"
#       (3006, 0050) Contour Data                        DS: Array of 2016 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002562
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "156"
#       (3006, 0050) Contour Data                        DS: Array of 468 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002561
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "674"
#       (3006, 0050) Contour Data                        DS: Array of 2022 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002561
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "158"
#       (3006, 0050) Contour Data                        DS: Array of 474 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002560
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "672"
#       (3006, 0050) Contour Data                        DS: Array of 2016 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002560
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "158"
#       (3006, 0050) Contour Data                        DS: Array of 474 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002559
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "670"
#       (3006, 0050) Contour Data                        DS: Array of 2010 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002559
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "158"
#       (3006, 0050) Contour Data                        DS: Array of 474 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002558
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "670"
#       (3006, 0050) Contour Data                        DS: Array of 2010 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002558
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002557
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "666"
#       (3006, 0050) Contour Data                        DS: Array of 1998 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002557
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002556
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "666"
#       (3006, 0050) Contour Data                        DS: Array of 1998 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002556
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002555
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "662"
#       (3006, 0050) Contour Data                        DS: Array of 1986 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002555
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002554
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "664"
#       (3006, 0050) Contour Data                        DS: Array of 1992 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002554
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002553
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "662"
#       (3006, 0050) Contour Data                        DS: Array of 1986 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002553
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002552
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "656"
#       (3006, 0050) Contour Data                        DS: Array of 1968 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002552
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002551
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "662"
#       (3006, 0050) Contour Data                        DS: Array of 1986 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002551
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "160"
#       (3006, 0050) Contour Data                        DS: Array of 480 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002550
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "664"
#       (3006, 0050) Contour Data                        DS: Array of 1992 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002550
# ...
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "140"
#       (3006, 0050) Contour Data                        DS: Array of 420 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002450
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "140"
#       (3006, 0050) Contour Data                        DS: Array of 420 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002449
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "616"
#       (3006, 0050) Contour Data                        DS: Array of 1848 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002449
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "34"
#       (3006, 0050) Contour Data                        DS: Array of 102 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002449
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "28"
#       (3006, 0050) Contour Data                        DS: Array of 84 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002448
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "612"
#       (3006, 0050) Contour Data                        DS: Array of 1836 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002447
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "608"
#       (3006, 0050) Contour Data                        DS: Array of 1824 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002446
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "604"
#       (3006, 0050) Contour Data                        DS: Array of 1812 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002445
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "598"
#       (3006, 0050) Contour Data                        DS: Array of 1794 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002444
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "598"
#       (3006, 0050) Contour Data                        DS: Array of 1794 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002443
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "596"
#       (3006, 0050) Contour Data                        DS: Array of 1788 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002442
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "594"
#       (3006, 0050) Contour Data                        DS: Array of 1782 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002441
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "592"
#       (3006, 0050) Contour Data                        DS: Array of 1776 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002440
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "590"
#       (3006, 0050) Contour Data                        DS: Array of 1770 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002439
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "590"
#       (3006, 0050) Contour Data                        DS: Array of 1770 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002438
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "590"
#       (3006, 0050) Contour Data                        DS: Array of 1770 elements
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "1"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [255, 0, 0]
#    (3006, 0040)  Contour Sequence  13 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002491
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "22"
#       (3006, 0050) Contour Data                        DS: Array of 66 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002490
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "28"
#       (3006, 0050) Contour Data                        DS: Array of 84 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002489
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "40"
#       (3006, 0050) Contour Data                        DS: Array of 120 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002488
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "42"
#       (3006, 0050) Contour Data                        DS: Array of 126 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002487
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "48"
#       (3006, 0050) Contour Data                        DS: Array of 144 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002486
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "46"
#       (3006, 0050) Contour Data                        DS: Array of 138 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002485
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "46"
#       (3006, 0050) Contour Data                        DS: Array of 138 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002484
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "46"
#       (3006, 0050) Contour Data                        DS: Array of 138 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002483
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "40"
#       (3006, 0050) Contour Data                        DS: Array of 120 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002482
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "30"
#       (3006, 0050) Contour Data                        DS: Array of 90 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002481
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "18"
#       (3006, 0050) Contour Data                        DS: Array of 54 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002480
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "22"
#       (3006, 0050) Contour Data                        DS: Array of 66 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.67009.30000018122100152352100002479
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: "20"
#       (3006, 0050) Contour Data                        DS: Array of 60 elements
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "2"
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  2 item(s) ----
#    (3006, 0082) Observation Number                  IS: "1"
#    (3006, 0084) Referenced ROI Number               IS: "1"
#    (3006, 0085) ROI Observation Label               SH: 'BODY'
#    (3006, 0086)  RT ROI Identification Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C44.9'
#       (0008, 0102) Coding Scheme Designator            SH: 'ICD-O-2'
#       (0008, 0104) Code Meaning                        LO: 'Skin, NOS'
#       ---------
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'EXTERNAL'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
#    (3006, 0082) Observation Number                  IS: "0"
#    (3006, 0084) Referenced ROI Number               IS: "2"
#    (3006, 0085) ROI Observation Label               SH: 'GTVp'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# (300e, 0002) Approval Status                     CS: 'UNAPPROVED'

# %%
import os
import numpy as np
import ants
os.makedirs(f"./seg/",exist_ok=True,)

nii = "/home/zhaosheng/4dct_test_nii/caowujun/caowujun_t4.nii"
nii_img = ants.image_read(nii)
nii_img += 1000
print(nii_img.shape)
for organ in rtstruct.get_roi_names():
# Loading the 3D Mask from within the RT Struct
    mask_3d = rtstruct.get_roi_mask_by_name(organ).transpose(1,0,2)
    mask = np.zeros(mask_3d.shape)
    mask[mask_3d]=1
    mask_3d_img = ants.from_numpy(mask)
    print(mask_3d_img.shape)
    # mask_3d_img.plot()
    ants.plot(nii_img,cmap='gray',slices=[100,125,150,200,250,300],axis=1,overlay=mask_3d_img,overlay_cmap='hot',overlay_alpha=0.5,cbar=True)
    ants.plot(mask_3d_img,cmap='gray',slices=[100,125,150,200,250,300],axis=1,overlay=mask_3d_img,overlay_cmap='hot',overlay_alpha=0.5,cbar=True)
    #[150:370,100:320,50:150]
    # Display one slice of the region
    # first_mask_slice = mask_3d[:, :, 100]
    # plt.imshow(first_mask_slice)
    # plt.colorbar()
    # plt.title(organ)
    # plt.show()
    print(mask_3d.shape)
    np.save(f"./seg/_{organ}.npy",mask_3d)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# (512, 512, 127)
# (512, 512, 127)
# (512, 512, 127)
# (512, 512, 127)
# (512, 512, 127)
