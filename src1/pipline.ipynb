# %%
import ants
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
real = "/mnt/zhaosheng/FNet/src1/results/fnet0921/199_yueshuqing_image_real.npy"
fake = "/mnt/zhaosheng/FNet/src1/results/fnet0921/199_yueshuqing_image_fake.npy"

# %%
real_npy = np.load(real)[0][0]
fake_npy = np.load(fake)[0][0]

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(real_npy[:,60,:].T,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(fake_npy[:,60,:].T,cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(real_npy[:,60,:].T,cmap='gray')
